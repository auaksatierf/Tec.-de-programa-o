# %% [markdown]
# <a href="https://colab.research.google.com/github/auaksatierf/Tec.-de-programa-o/blob/main/Eng_soft_6nov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Operadores

# %%
5+5/5*5
# Out:
# 10.0

# %%
4**(4/2)+7
# Out:
# 23.0

# %%
a=int(input("Digite um número: "))
b=int(input("DIgite um numero:"))
soma= a+b
print("A soma é", soma)
# Out:
# Digite um número: 23
# DIgite um numero:32
# A soma é 55

# %%
2**3
# Out:
# 8

# %%
23/7
# Out:
# 3.2857142857142856

# %%
23%7
# Out:
# 2

# %% [markdown]
# #Exercicio

# %%
#1
num1 = 2
num2 = 10
soma = num1+num2
print(soma)
# Out:
# 12

# %%
#2
nota=float(input("digite sua nota"))
nota2=float(input("digite sua nota"))
soma= nota+nota2
media= soma/2
print(media)
# Out:
# digite sua nota5.0
# digite sua nota7.0
# 6.0

# %%
#3
nome= kaua
